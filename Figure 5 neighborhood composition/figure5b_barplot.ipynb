# %% [markdown]
# # Figure 5b - barplot showing composition of T cell neighborhoods in [-40, 0] and [0, 40] regions

# %%
require(tidyverse)
require(data.table)

# %%
cell_metadata = fread('Cell-Metadata-Tcd8-CXCL13-gdlikePD1-Neighboring-Epithelial-[-40, 40] (1).csv')
glimpse(cell_metadata)

# %%
unique(cell_metadata$KNN_celltype_v2)

# %%
ggplot(cell_metadata) +
    geom_bar(aes(x = Epi_Stroma, fill = KNN_celltype_v2))
